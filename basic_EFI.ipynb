# %%
from viresclient import SwarmRequest
import datetime as dt
# %matplotlib inline

# %%
request = SwarmRequest()
request.available_measurements("EFI")
# Out:
# ['U_orbit',
#  'Ne',
#  'Ne_error',
#  'Te',
#  'Te_error',
#  'Vs',
#  'Vs_error',
#  'Flags_LP',
#  'Flags_Ne',
#  'Flags_Te',
#  'Flags_Vs']

# %%
request.set_collection("SW_OPER_EFIA_LP_1B")
request.set_products(
    measurements=['U_orbit',
                 'Ne',
                 'Ne_error',
                 'Te',
                 'Te_error',
                 'Vs',
                 'Vs_error',
                 'Flags_LP',
                 'Flags_Ne',
                 'Flags_Te',
                 'Flags_Vs']
)
data = request.get_between(
    dt.datetime(2016,1,1),
    dt.datetime(2016,1,2)
)
# Out:
# [1/1] Processing:  100%|██████████|  [ Elapsed: 00:01, Remaining: 00:00 ]
#       Downloading: 100%|██████████|  [ Elapsed: 00:01, Remaining: 00:00 ] (16.076MB)

# %%
df = data.as_dataframe()
df.head()
# Out:
#                               Spacecraft   Latitude  Longitude      Radius  \
# 2016-01-01 00:00:00.197000027          A -72.511716  92.799630  6833852.72
# 2016-01-01 00:00:00.696000099          A -72.543238  92.813944  6833853.09
# 2016-01-01 00:00:01.197000027          A -72.574886  92.828370  6833853.91
# 2016-01-01 00:00:01.696000099          A -72.606406  92.842799  6833854.27
# 2016-01-01 00:00:02.197000027          A -72.638051  92.857342  6833855.09
#
#                                 U_orbit        Ne      Ne_error       Te  \
# 2016-01-01 00:00:00.197000027  7604.407  126188.4  9.999990e+09  2945.20
# 2016-01-01 00:00:00.696000099  7604.398  127792.9  9.999990e+09  2891.97
# 2016-01-01 00:00:01.197000027  7604.389  132515.3  9.999990e+09  2921.96
# 2016-01-01 00:00:01.696000099  7604.380  137933.0  9.999990e+09  2936.74
# 2016-01-01 00:00:02.197000027  7604.371  138913.8  9.999990e+09  2870.09
#
#                                    Te_error     Vs      Vs_error  Flags_LP  \
# 2016-01-01 00:00:00.197000027  9.999990e+09 -2.201  9.999990e+09         1
# 2016-01-01 00:00:00.696000099  9.999990e+09 -2.193  9.999990e+09         1
# 2016-01-01 00:00:01.197000027  9.999990e+09 -2.200  9.999990e+09         1
# 2016-01-01 00:00:01.696000099  9.999990e+09 -2.194  9.999990e+09         1
# 2016-01-01 00:00:02.197000027  9.999990e+09 -2.190  9.999990e+09         1
#
#                                Flags_Ne  Flags_Te  Flags_Vs
# 2016-01-01 00:00:00.197000027        20        20        20
# 2016-01-01 00:00:00.696000099        20        20        20
# 2016-01-01 00:00:01.197000027        20        20        20
# 2016-01-01 00:00:01.696000099        20        20        20
# 2016-01-01 00:00:02.197000027        20        20        20

# %%
df.plot(y=["Ne", "Te", "Vs"], subplots=True, figsize=(20,5));

# %%
df.plot(x="Latitude", y="Ne");
